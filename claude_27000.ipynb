# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushee-Seeburrun/ASAG-with-Data-Augmentation/blob/main/claude_27000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os,json,time, random
import pandas as pd
import requests
from google.colab import userdata

# %%
readpath = "/content/drive/MyDrive/Data Augmentation/Claude/claude_22000"
file = pd.read_csv(f"{readpath}/complete_augment_22000.csv")

# %%
import re, unicodedata
def clean_rows(s):
    s = str(s)
    s = unicodedata.normalize("NFKC", s)
    s = s.replace("\u00A0", " ")
    s = re.sub(r"\s+", " ", s).strip()

    #removing "^p" or "^P" characters from the remaining original records and anywhere else if there are any (a few)
    s = s.replace("^p", " ").replace("^P", " ")
    s = re.sub(r"\s+", " ", s).strip()

    return s

file["EssayText"] = file["EssayText"].map(clean_rows)

file["type"] = file["type"].fillna("").astype(str).str.strip().str.lower()

#creating a standardised version of each answer to detect duplicates , normalisation is done to prevent a sentence from being treated as two different things
file["EssayText_normalise"] = file["EssayText"].map(clean_rows).map(lambda x: x.lower())

# %%
df = file.copy()
df["_norm"] = df["EssayText"].map(clean_rows).map(str.lower)

# mark duplicates within score
df["is_dup"] = df.duplicated(subset=["Score2", "_norm"], keep=False)

# see where duplicates come from
dup_source_counts = (
    df[df["is_dup"]]
    .groupby("type")
    .size()
)

print(dup_source_counts)
# Out:
# type
#                268
# paraphrased     11
# dtype: int64

# %%
#to prioritise fairness and avoid bias towards any score
total = 27000
genperscore = total // 4

#counting the number of unique answers per score that exist in the dataset
uniqueScoreCount = (
    file.drop_duplicates(subset=["Score2", "EssayText_normalise"])      #looking at each answer within a score, if two answers have the same score and normalised text, only one is kept
      .groupby("Score2").size()     #counts the number of rows in each score group (unique counts)
      .reindex([0,1,2,3], fill_value=0)       #ensures that all the four scoers appear, even those with zero rows (it will be filled with "0")
)

generateScore = (genperscore - uniqueScoreCount).clip(lower=0).astype(int)

print("The current totalrows per score: ", file["Score2"].value_counts().sort_index().to_dict())
print("Current unique rows per score: ", uniqueScoreCount.to_dict())
print("The number of unique paraphrases to be added per score: ", generateScore.to_dict())

print("Sanity check: \n")
for s in [0,1,2,3]:
  print(s,uniqueScoreCount[s], "+" , generateScore[s], "=", uniqueScoreCount[s] + generateScore[s])
# Out:
# The current totalrows per score:  {0: 5548, 1: 5553, 2: 5526, 3: 5500}
# Current unique rows per score:  {0: 5491, 1: 5500, 2: 5497, 3: 5496}
# The number of unique paraphrases to be added per score:  {0: 1259, 1: 1250, 2: 1253, 3: 1254}
# Sanity check:
#
# 0 5491 + 1259 = 6750
# 1 5500 + 1250 = 6750
# 2 5497 + 1253 = 6750
# 3 5496 + 1254 = 6750

# %%
#selecting all original rows to build anchor pool to avoid claude learning from claude.
original = file[file["type"] != "paraphrased"].copy()
original["EssayText"] = original["EssayText"].map(clean_rows)


#detecting anchors that are incomplete, weak and not good learning materials before sending them as anchors
weak_resp = re.compile(
    #r is a raw string - prevents backslash issues
    r"\b(i\s*don't\s*know|i\s*do\s*not\s*know|idk|not\s*sure|no\s*idea|unsure|can't\s*remember)\b",    #creating a pattern to identify answers like i dont know unsure etc...
    re.IGNORECASE
)

def is_incomplete_weak(text: str) -> bool:
  t = text.strip()

  if len(t) < 40:
    return True

  bad_ends = (" to", " and", " or", " because"," but", " so", " when", " if", " which" )
  if t.lower().endswith(bad_ends):
    return True

  if weak_resp.search(t):   #looks for the weak responses and reject them
    return True

  if t.lower() in ("^p","a)","b)","a.","b.","1.","2.","1)","2)"):
    return True

  return False      #runs when neither of the bad conditions are met


score_anchors = {
    s: original.loc[original["Score2"] == s, "EssayText"].tolist()
    for s in [0, 1, 2, 3]
}
for s in [0, 1, 2, 3]:
  anc_ans_before = len(score_anchors[s])
  score_anchors[s] = [
      clean_rows(x)
      for x in score_anchors[s]
      if not is_incomplete_weak(x)
  ]

  seen = set()
  unq = []
  for x in score_anchors[s]:
    key = clean_rows(x).lower()
    if key in seen:
      continue
    seen.add(key)
    unq.append(x)
  score_anchors[s] = unq

  anc_ans_after = len(score_anchors[s])
  print(f"Score {s} anchors filtered: {anc_ans_before} ==> {anc_ans_after}")

for s in [0,1,2,3]:
   random.shuffle(score_anchors[s])
# Out:
# Score 0 anchors filtered: 5424 ==> 4667
# Score 1 anchors filtered: 4518 ==> 4418
# Score 2 anchors filtered: 3225 ==> 3184
# Score 3 anchors filtered: 598 ==> 592

# %%
#all the answers that already exist in the dataset
existing_data = set(zip(file["Score2"], file["EssayText_normalise"]))

#this function checks if a paraphrase is safe to accept , seen_batch tracks what has already been accepted within the current response from Claude
def new_phrase(score, text, seen_batch) :

  #claening the claude output
  text = clean_rows(text)
  #if text has same score and same normalized text ---> its a duplicate
  key = (score, text.lower())
  return(key not in existing_data) and (key not in seen_batch), text

# %%
#strictly blocking starter commentary like "To replicate, based on, the student"
bad_start = re.compile(
    r'^\s*["\'(\[]*\s*('
    r'the student\b|the student\'s\b|this answer\b|the answer\b|'
    r'based on\b|to replicate\b|overall\b|in conclusion\b|according to\b'
    r')',
    re.IGNORECASE
)

def has_badstart(t: str) -> bool:
  return bad_start.search(t) is not None

def sentence_cutoff(t:str) -> bool:
  t = t.strip()
  bad_endings = (" to", " and", " or", " because"," but", " so", " when", " if", " which" )

  if t.lower().endswith(bad_endings):
    return True

  if len(t) < 40 and t[-1] not in ".?!":
    return True

  return False
def valid_paraphrase(text:str) -> bool:
  t = clean_rows(text)
  t1 = t.lower()

  if "^p" in t1:
    return False
  if has_badstart(t):
    return False
  if sentence_cutoff(t):
    return False
  if len(t) < 60:
    return False
  if re.match(r"^\s*\d+\.", t):
    return False
  if re.match(r"^\s*[a-dA-D][\)\.]\s+", t):
    return False
  if "(a)" in t1 or "(b)" in t1:
    return False
  if weak_resp.search(t1):
    return False

  return True

# %%
#setting the static rules to apply prompt caching
static_sys = """
You are helping with ASAG data augmentation.
Task: Paraphrase student answers.
Rules:
-Keep the SAME meaning and the SAME level of correctness.
-Do not add or remove information.
-Do not reuse any 4 consecutive words from the original answer.
-Do not output labels like "Student answer: " or "Paraphrased answer:" or any commentary.
-Return only valid JSON(no markdown).
-Output must be a JSON array of strings (each string is only the paraphrased answer), same order as input.
-Escape any quotes inside the strings with backslash.
-Write in a more natural tone, like a student answering an exam question.
-Write strictly in English.
-Avoid repetitive sentence starters. Vary the opening sentences each time.
- Do NOT begin answers with phrases such as: "To replicate the experiment", "Based on the data", "The student's data indicates", "To replicate".
- DO NOT refer to the response as a student's work (no "the student", no "the student's answer").
-Do NOT use lettered formatting like "a)" "b)".
-DO NOT output symbols like "^p".
-Do NOT use numbered lists (e.g., "1.", "2.", "3.") unless the original answer is a list.
"""

# %%
def dynamic_prompt(textlist):
  return(
      "Paraphrase the following student answers.\n Return only a valid JSON array of strings,same order.\n Do not add labels like 'student answer:' or 'paraphrased answer:'.\n" + json.dumps(textlist,ensure_ascii=False)
  )

# %%
claude_api_key = userdata.get('Claude_key')

# %%
def claude_call(prompt, max_retries=10):
  for attempt in range(max_retries):
    resp= requests.post("https://api.anthropic.com/v1/messages",
        headers={
            "x-api-key":claude_api_key,
            "anthropic-version": "2023-06-01",
            "content-type": "application/json"
      },
        json={
            "model": "claude-3-haiku-20240307",
            "max_tokens": 2500,
            "system": [{
                "type":"text",
                "text": static_sys,
                "cache_control": {"type": "ephemeral"}
            }],
            "messages": [{
                "role":"user",
                "content": [{"type": "text", "text" : prompt}]
            }]
        },
        timeout=90
    )
    if resp.status_code == 200:
      return resp.json()["content"][0]["text"]
    if resp.status_code in (429, 500, 502, 503, 529):
        wait = min(90, (2 ** attempt)) + random.uniform(0.5, 3.0)
        print(f"Claude busy ({resp.status_code}). Backing off {wait:.1f}s (attempt {attempt+1}/{max_retries})")
        time.sleep(wait)
        continue

    print("Claude API error: ", resp.status_code)
    print(resp.text[:300])
    return None
  print("Claude API: exceeded retries; skipping this batch.")
  return None

# %%
def parse_json_array(text):
    if text is None:
        return None
    t = text.strip()
    #a quick sanity checks to say that the sentence must start with [ and end with ]
    if not (t.startswith("[") and t.endswith("]")):
        return None
    try:
        data = json.loads(text)
        if isinstance(data, list) and all(isinstance(x, str) for x in data):
            return data
        return None
    except:
        return None

# %%
anchor_in = {s: 0 for s in [0,1,2,3]}

def next_anchor(score,k):
  anchor_pool = score_anchors[score]
  if not anchor_pool:
    return []

  out = []
  for x in range(k):
    out.append(anchor_pool[anchor_in[score] % len(anchor_pool)])
    anchor_in[score] += 1
  return out

# %%
batch_size = 30
checkpt = 200

accepted_para = {0:0, 1:0, 2:0, 3:0}
new_rows = []

bad_json_streak = 0
startTime = time.time()

def print_progress(extra_note=""):
    elapsed = (time.time() - startTime) / 60
    totalAdded = sum(accepted_para.values())
    totalNeeded = int(generateScore.sum())

    print(
        f"Progress: {totalAdded}/{totalNeeded} | "
        f"accepted={accepted_para} | Time elapsed={elapsed:.2f} mins {extra_note}"
    )

#keeps generating paraphrases until the required number has been added for all scores
while sum(accepted_para.values()) < int(generateScore.sum()):


    remaining = {s: int(generateScore[s] - accepted_para[s]) for s in [0,1,2,3]}
    #here the scores completed are being removed and only those that still need augmentation are kept
    remaining = {s:r for s,r in remaining.items() if r > 0}

    #if all scores completed, the loop is exited
    if not remaining:
        break

    #pick the most underfilled score
    score = max(remaining, key=remaining.get)

    # get anchors by cycling through originals to avoid repeating the same anchors too often
    k = min(batch_size, len(score_anchors[score]))

    if k == 0:
      print(f"No usable anchors left for score {score}. Marking score as complete to avoid infinite loop.")
      accepted_para[score] = int(generateScore[score])
      continue

    anchors = next_anchor(score, k)

    #converts anchor list -->  json-based prompt
    prompt = dynamic_prompt(anchors)
    #sends the request to Claude , returns a JSON array of paraphrases
    result = claude_call(prompt)

    if result is None:
        print("API failed. Retrying...")
        time.sleep(30)
        continue

    #converts the responses from Claude into a lsit
    paraphrases = parse_json_array(result)

    if paraphrases is None:
        bad_json_streak += 1
        print("Bad JSON from Claude. Retrying. (streak:", bad_json_streak, ")")
        print(result[:250])
        time.sleep(6)

        if bad_json_streak >= 10:
            print("Too many bad JSON responses. Stopping for safety.")
            break
        continue

    bad_json_streak = 0

    #this blocks dupes within the same CLaude response
    seen_batch = set()
    added = 0

    for para in paraphrases:
        if accepted_para[score] >= int(generateScore[score]):
            break
        if para is None:
            continue

        #cleaning the Claude output and checks for dupes
        ok, cleaned = new_phrase(score, para, seen_batch)
        if not ok:
            continue

        #strict validation (starters, ^p, formatting, cutoff, too short, weak phrases)
        if not valid_paraphrase(cleaned):
            continue


        # accept
        new_rows.append({
            "EssayText": cleaned,
            "Score2": score,
            "type": "paraphrased"
        })

        #below ensures that the future batches dont introduce same paraphrases again
        n = (score, clean_rows(cleaned).lower())
        existing_data.add(n)
        seen_batch.add(n)

        accepted_para[score] += 1
        added += 1

    print_progress(extra_note=f"| Score {score} +{added}")
    time.sleep(1.0)

print("Generation done. New rows created:", len(new_rows))
# Out:
# Progress: 26/5016 | accepted={0: 26, 1: 0, 2: 0, 3: 0} | Time elapsed=0.11 mins | Score 0 +26
# Claude busy (529). Backing off 3.1s (attempt 1/10)
# Progress: 31/5016 | accepted={0: 26, 1: 0, 2: 0, 3: 5} | Time elapsed=0.33 mins | Score 3 +5
# Progress: 57/5016 | accepted={0: 26, 1: 0, 2: 26, 3: 5} | Time elapsed=0.54 mins | Score 2 +26
# Progress: 83/5016 | accepted={0: 26, 1: 26, 2: 26, 3: 5} | Time elapsed=0.69 mins | Score 1 +26
# Progress: 91/5016 | accepted={0: 26, 1: 26, 2: 26, 3: 13} | Time elapsed=0.90 mins | Score 3 +8
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The initial step involves mRNA attaching to the ribosome to hold it in place. Next, tRNA brings the complementary anticodons and they match with the base pairs. In the third step, another tRNA brings another anticodon and the amino acids at the en
# Progress: 100/5016 | accepted={0: 26, 1: 26, 2: 26, 3: 22} | Time elapsed=1.28 mins | Score 3 +9
# Progress: 126/5016 | accepted={0: 52, 1: 26, 2: 26, 3: 22} | Time elapsed=1.45 mins | Score 0 +26
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "A ribosome attaches to the mRNA and translation occurs. Codons in the mRNA are matched with corresponding anticodons in the tRNA, bringing the correct amino acids. Peptide bonds form between the amino acids to construct the new protein.",
# "To repl
# Progress: 134/5016 | accepted={0: 52, 1: 26, 2: 26, 3: 30} | Time elapsed=1.81 mins | Score 3 +8
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "
# Progress: 1855/5016 | accepted={0: 485, 1: 453, 2: 461, 3: 456} | Time elapsed=18.41 mins | Score 0 +28
# Progress: 1862/5016 | accepted={0: 485, 1: 453, 2: 461, 3: 463} | Time elapsed=18.49 mins | Score 3 +7
# Progress: 1884/5016 | accepted={0: 485, 1: 475, 2: 461, 3: 463} | Time elapsed=18.60 mins | Score 1 +22
# Progress: 1910/5016 | accepted={0: 485, 1: 475, 2: 487, 3: 463} | Time elapsed=18.76 mins | Score 2 +26
# Progress: 1924/5016 | accepted={0: 485, 1: 475, 2: 487, 3: 477} | Time elapsed=18.90 mins | Score 3 +14
# Progress: 1931/5016 | accepted={0: 485, 1: 475, 2: 487, 3: 484} | Time elapsed=19.01 mins | Score 3 +7
# Progress: 1953/5016 | accepted={0: 485, 1: 497, 2: 487, 3: 484} | Time elapsed=19.21 mins | Score 1 +22
# Progress: 1974/5016 | accepted={0: 506, 1: 497, 2: 487, 3: 484} | Time elapsed=19.34 mins | Score 0 +21
# Progress: 1986/5016 | accepted={0: 506, 1: 497, 2: 487, 3: 496} | Time elapsed=19.57 mins | Score 3 +12
# Progress: 2009/5016 | accepted={0: 506, 1: 497, 2: 510, 3: 496} | Time elapsed=19.80 mins | Score 2 +23
# Progress: 2028/5016 | accepted={0: 506, 1: 497, 2: 510, 3: 515} | Time elapsed=19.96 mins | Score 3 +19
# Progress: 2057/5016 | accepted={0: 535, 1: 497, 2: 510, 3: 515} | Time elapsed=20.09 mins | Score 0 +29
# Progress: 2081/5016 | accepted={0: 535, 1: 521, 2: 510, 3: 515} | Time elapsed=20.28 mins | Score 1 +24
# Progress: 2105/5016 | accepted={0: 535, 1: 521, 2: 534, 3: 515} | Time elapsed=20.42 mins | Score 2 +24
# Progress: 2116/5016 | accepted={0: 535, 1: 521, 2: 534, 3: 526} | Time elapsed=20.65 mins | Score 3 +11
# Progress: 2144/5016 | accepted={0: 535, 1: 549, 2: 534, 3: 526} | Time elapsed=20.78 mins | Score 1 +28
# Progress: 2155/5016 | accepted={0: 535, 1: 549, 2: 534, 3: 537} | Time elapsed=20.93 mins | Score 3 +11
# Progress: 2180/5016 | accepted={0: 560, 1: 549, 2: 534, 3: 537} | Time elapsed=21.06 mins | Score 0 +25
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "After reading the group's procedure, I would need to know the key components of the experiment, such as the specific samples used. The procedure does not mention marble, limestone, wood, and plastic as the samples. I would also require more detail
# Progress: 2210/5016 | accepted={0: 560, 1: 549, 2: 564, 3: 537} | Time elapsed=21.55 mins | Score 2 +30
# Progress: 2216/5016 | accepted={0: 560, 1: 549, 2: 564, 3: 543} | Time elapsed=21.62 mins | Score 3 +6
# Progress: 2226/5016 | accepted={0: 560, 1: 549, 2: 564, 3: 553} | Time elapsed=21.80 mins | Score 3 +10
# Bad JSON from Claude. Retrying. (streak: 1 )
# Here is a JSON array of paraphrased student answers:
#
# [
# "The cell membrane controls what goes in and out of the cell. The nucleus acts like a brain, directing the cell's activities.",
# "Dark gray should keep the dog house at a moderate temperature, no
# Progress: 2248/5016 | accepted={0: 560, 1: 571, 2: 564, 3: 553} | Time elapsed=22.13 mins | Score 1 +22
# Progress: 2263/5016 | accepted={0: 560, 1: 571, 2: 564, 3: 568} | Time elapsed=22.28 mins | Score 3 +15
# Progress: 2287/5016 | accepted={0: 584, 1: 571, 2: 564, 3: 568} | Time elapsed=22.44 mins | Score 0 +24
# Progress: 2307/5016 | accepted={0: 584, 1: 571, 2: 584, 3: 568} | Time elapsed=22.64 mins | Score 2 +20
# Progress: 2323/5016 | accepted={0: 584, 1: 571, 2: 584, 3: 584} | Time elapsed=22.83 mins | Score 3 +16
# Progress: 2351/5016 | accepted={0: 584, 1: 599, 2: 584, 3: 584} | Time elapsed=22.98 mins | Score 1 +28
# Progress: 2378/5016 | accepted={0: 611, 1: 599, 2: 584, 3: 584} | Time elapsed=23.12 mins | Score 0 +27
# Progress: 2392/5016 | accepted={0: 611, 1: 599, 2: 584, 3: 598} | Time elapsed=23.29 mins | Score 3 +14
# Progress: 2402/5016 | accepted={0: 611, 1: 599, 2: 594, 3: 598} | Time elapsed=23.38 mins | Score 2 +10
# Progress: 2429/5016 | accepted={0: 611, 1: 599, 2: 621, 3: 598} | Time elapsed=23.58 mins | Score 2 +27
# Bad JSON from Claude. Retrying. (streak: 1 )
# Here is the valid JSON array of strings, with the student answers paraphrased:
#
# ["Based on the data, plastic type A was the least stretchable and most durable, while plastic type B was the most stretchable and least durable. To improve the experiment
# Bad JSON from Claude. Retrying. (streak: 2 )
# [
# "According to the data, plastic type B had the most stretchability, while plastic type A had the least. To improve the experiment, the student could have specified the exact amount of weight added and the starting and ending measurements for each p
# Progress: 2438/5016 | accepted={0: 611, 1: 599, 2: 621, 3: 607} | Time elapsed=24.25 mins | Score 3 +9
# Progress: 2465/5016 | accepted={0: 611, 1: 626, 2: 621, 3: 607} | Time elapsed=24.42 mins | Score 1 +27
# Progress: 2492/5016 | accepted={0: 638, 1: 626, 2: 621, 3: 607} | Time elapsed=24.57 mins | Score 0 +27
# Progress: 2502/5016 | accepted={0: 638, 1: 626, 2: 621, 3: 617} | Time elapsed=24.77 mins | Score 3 +10
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "To replicate the experiment, the group should list the type of material they used. They should also provide the amount of vinegar they added and explain how they measured the difference in mass at the end.",
# "Osmosis is the diffusion of water thro
# Progress: 2512/5016 | accepted={0: 638, 1: 626, 2: 621, 3: 627} | Time elapsed=25.25 mins | Score 3 +10
# Progress: 2536/5016 | accepted={0: 638, 1: 626, 2: 645, 3: 627} | Time elapsed=25.43 mins | Score 2 +24
# Progress: 2549/5016 | accepted={0: 638, 1: 626, 2: 645, 3: 640} | Time elapsed=25.67 mins | Score 3 +13
# Progress: 2566/5016 | accepted={0: 638, 1: 643, 2: 645, 3: 640} | Time elapsed=25.80 mins | Score 1 +17
# Progress: 2592/5016 | accepted={0: 664, 1: 643, 2: 645, 3: 640} | Time elapsed=25.90 mins | Score 0 +26
# Progress: 2600/5016 | accepted={0: 664, 1: 643, 2: 645, 3: 648} | Time elapsed=26.04 mins | Score 3 +8
# Progress: 2621/5016 | accepted={0: 664, 1: 643, 2: 666, 3: 648} | Time elapsed=26.21 mins | Score 2 +21
# Bad JSON from Claude. Retrying. (streak: 1 )
# Here is a JSON array of paraphrased answers:
#
# [
# "The key things you would need are the samples and the process after step 6.",
# "The giant panda and the koala are similar because they are both highly specialized eaters, consuming almost exclusively ba
# Bad JSON from Claude. Retrying. (streak: 2 )
# [
# "The term 'invasive' in this article refers to species that spread and occupy new territories, displacing native species. The article notes that some people see this term as unfairly judgmental, preferring to call them 'introduced' instead.",
# "The
# Bad JSON from Claude. Retrying. (streak: 3 )
# [
# "Pandas and koalas are similar because they both have very specialized diets, with pandas eating only bamboo and koalas eating only eucalyptus leaves. In contrast, pythons are generalists and can eat a wide variety of foods.",
# "Based on the data, t
# Progress: 2646/5016 | accepted={0: 664, 1: 668, 2: 666, 3: 648} | Time elapsed=27.08 mins | Score 1 +25
# Progress: 2661/5016 | accepted={0: 664, 1: 668, 2: 666, 3: 663} | Time elapsed=27.20 mins | Score 3 +15
# Progress: 2690/5016 | accepted={0: 693, 1: 668, 2: 666, 3: 663} | Time elapsed=27.36 mins | Score 0 +29
# Progress: 2694/5016 | accepted={0: 693, 1: 668, 2: 666, 3: 667} | Time elapsed=27.58 mins | Score 3 +4
# Progress: 2718/5016 | accepted={0: 693, 1: 668, 2: 690, 3: 667} | Time elapsed=27.83 mins | Score 2 +24
# Progress: 2726/5016 | accepted={0: 693, 1: 668, 2: 690, 3: 675} | Time elapsed=27.97 mins | Score 3 +8
# Progress: 2752/5016 | accepted={0: 693, 1: 694, 2: 690, 3: 675} | Time elapsed=28.14 mins | Score 1 +26
# Progress: 2765/5016 | accepted={0: 693, 1: 694, 2: 690, 3: 688} | Time elapsed=28.34 mins | Score 3 +13
# Progress: 2789/5016 | accepted={0: 717, 1: 694, 2: 690, 3: 688} | Time elapsed=28.49 mins | Score 0 +24
# Progress: 2802/5016 | accepted={0: 717, 1: 694, 2: 690, 3: 701} | Time elapsed=28.70 mins | Score 3 +13
# Progress: 2822/5016 | accepted={0: 717, 1: 694, 2: 710, 3: 701} | Time elapsed=28.86 mins | Score 2 +20
# Progress: 2842/5016 | accepted={0: 717, 1: 714, 2: 710, 3: 701} | Time elapsed=28.99 mins | Score 1 +20
# Progress: 2852/5016 | accepted={0: 717, 1: 714, 2: 710, 3: 711} | Time elapsed=29.19 mins | Score 3 +10
# Progress: 2876/5016 | accepted={0: 717, 1: 714, 2: 734, 3: 711} | Time elapsed=29.38 mins | Score 2 +24
# Progress: 2896/5016 | accepted={0: 717, 1: 714, 2: 734, 3: 731} | Time elapsed=29.62 mins | Score 3 +20
# Progress: 2919/5016 | accepted={0: 740, 1: 714, 2: 734, 3: 731} | Time elapsed=29.76 mins | Score 0 +23
# Progress: 2943/5016 | accepted={0: 740, 1: 738, 2: 734, 3: 731} | Time elapsed=29.91 mins | Score 1 +24
# Progress: 2951/5016 | accepted={0: 740, 1: 738, 2: 734, 3: 739} | Time elapsed=30.04 mins | Score 3 +8
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "Based on the data, it appears that the different plastic samples responded in varying ways when weight was applied, with some staying the same length, some growing longer, and others becoming shorter. To improve the experiment, the student could h
# Progress: 3380/5016 | accepted={0: 864, 1: 833, 2: 840, 3: 843} | Time elapsed=34.38 mins | Score 3 +9
# Progress: 3405/5016 | accepted={0: 864, 1: 858, 2: 840, 3: 843} | Time elapsed=34.57 mins | Score 1 +25
# Progress: 3422/5016 | accepted={0: 864, 1: 858, 2: 857, 3: 843} | Time elapsed=34.72 mins | Score 2 +17
# Progress: 3436/5016 | accepted={0: 864, 1: 858, 2: 857, 3: 857} | Time elapsed=34.90 mins | Score 3 +14
# Progress: 3445/5016 | accepted={0: 864, 1: 858, 2: 857, 3: 866} | Time elapsed=35.11 mins | Score 3 +9
# Progress: 3470/5016 | accepted={0: 864, 1: 858, 2: 882, 3: 866} | Time elapsed=35.28 mins | Score 2 +25
# Progress: 3496/5016 | accepted={0: 890, 1: 858, 2: 882, 3: 866} | Time elapsed=35.42 mins | Score 0 +26
# Progress: 3517/5016 | accepted={0: 890, 1: 879, 2: 882, 3: 866} | Time elapsed=35.54 mins | Score 1 +21
# Progress: 3526/5016 | accepted={0: 890, 1: 879, 2: 882, 3: 875} | Time elapsed=35.67 mins | Score 3 +9
# Progress: 3532/5016 | accepted={0: 890, 1: 879, 2: 882, 3: 881} | Time elapsed=35.83 mins | Score 3 +6
# Progress: 3544/5016 | accepted={0: 890, 1: 879, 2: 882, 3: 893} | Time elapsed=36.00 mins | Score 3 +12
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The author divides the passage into sections to inform the reader about the content of each section and what will be covered next.",
# "1. Phagocytosis - It traps certain materials and allows them to enter the cell
# 2. Exocytosis - Pushes certain mat
# Progress: 3570/5016 | accepted={0: 890, 1: 905, 2: 882, 3: 893} | Time elapsed=36.40 mins | Score 1 +26
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "Specify the types of samples being used in step 1. Indicate the amount of vinegar to be used in step 2. Provide the dimensions of the container in step 2. In step 4, give instructions on how to properly remove the samples from the containers.",
# "I
# Bad JSON from Claude. Retrying. (streak: 2 )
# [
# "The lighter the color, the cooler the doghouse will be, making it more comfortable. The white lid had an average temperature of 42°C, which was 3°C cooler than the other lids.",
# "Paul can relate to Mr. Leonard because they both have difficulties -
# Bad JSON from Claude. Retrying. (streak: 3 )
# [
# "Rose shows care for her sister Anna in their conversation. She asks if Anna is worried, demonstrating concern for her emotional state. Rose also mentions their father working hard to send their brother Paul to college, showing she cares about her
# Progress: 3589/5016 | accepted={0: 890, 1: 905, 2: 901, 3: 893} | Time elapsed=37.29 mins | Score 2 +19
# Progress: 3614/5016 | accepted={0: 915, 1: 905, 2: 901, 3: 893} | Time elapsed=37.47 mins | Score 0 +25
# Progress: 3626/5016 | accepted={0: 915, 1: 905, 2: 901, 3: 905} | Time elapsed=37.60 mins | Score 3 +12
# Progress: 3655/5016 | accepted={0: 915, 1: 905, 2: 930, 3: 905} | Time elapsed=37.82 mins | Score 2 +29
# Progress: 3668/5016 | accepted={0: 915, 1: 905, 2: 930, 3: 918} | Time elapsed=38.04 mins | Score 3 +13
# Progress: 4395/5016 | accepted={0: 1112, 1: 1087, 2: 1106, 3: 1090} | Time elapsed=46.57 mins | Score 0 +22
# Progress: 4408/5016 | accepted={0: 1112, 1: 1087, 2: 1106, 3: 1103} | Time elapsed=46.81 mins | Score 3 +13
# Progress: 4435/5016 | accepted={0: 1112, 1: 1114, 2: 1106, 3: 1103} | Time elapsed=46.97 mins | Score 1 +27
# Progress: 4440/5016 | accepted={0: 1112, 1: 1114, 2: 1106, 3: 1108} | Time elapsed=47.11 mins | Score 3 +5
# Progress: 4465/5016 | accepted={0: 1137, 1: 1114, 2: 1106, 3: 1108} | Time elapsed=47.26 mins | Score 0 +25
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "When Paul learned about Mr. Leonard's background, it made him feel less alone in his struggles with reading. He realized that Mr. Leonard, who had been a talented athlete, also had trouble reading. This knowledge motivated Paul to work harder and
# Bad JSON from Claude. Retrying. (streak: 2 )
# [
# "To determine the proper amount of vinegar to use, the size of the containers, and the type of scale to use, I would need more details.",
# "The white paint color would help keep the doghouse cooler inside by reflecting more heat compared to darker c
# Progress: 4491/5016 | accepted={0: 1137, 1: 1114, 2: 1132, 3: 1108} | Time elapsed=47.93 mins | Score 2 +26
# Progress: 4498/5016 | accepted={0: 1137, 1: 1114, 2: 1132, 3: 1115} | Time elapsed=48.05 mins | Score 3 +7
# Progress: 4504/5016 | accepted={0: 1137, 1: 1114, 2: 1132, 3: 1121} | Time elapsed=48.19 mins | Score 3 +6
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "Pandas in China and koalas in Australia are both specialized eaters, with pandas relying almost solely on bamboo and koalas subsisting almost entirely on eucalyptus leaves. This is different from pythons, which are generalists that can adapt to a
# Bad JSON from Claude. Retrying. (streak: 2 )
# Here is the paraphrased JSON array of student answers:
#
# [
#   "Another way the student could have improved the experiment is by using a higher quality brand of plastic or simply repeating the experiment.",
#   "The best color for a dog house is white bec
# Progress: 4528/5016 | accepted={0: 1137, 1: 1138, 2: 1132, 3: 1121} | Time elapsed=48.82 mins | Score 1 +24
# Progress: 4536/5016 | accepted={0: 1137, 1: 1138, 2: 1132, 3: 1129} | Time elapsed=49.00 mins | Score 3 +8
# Progress: 4553/5016 | accepted={0: 1137, 1: 1138, 2: 1132, 3: 1146} | Time elapsed=49.16 mins | Score 3 +17
# Progress: 4580/5016 | accepted={0: 1164, 1: 1138, 2: 1132, 3: 1146} | Time elapsed=49.31 mins | Score 0 +27
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "Now that Paul sees Mr. Leonard as an equal, he can understand why Mr. Leonard is helping him and is thankful for it. Paul then realizes that he can pay back Mr. Leonard by teaching him to read.",
# "The experiment showed that the four different poly
# Progress: 4600/5016 | accepted={0: 1164, 1: 1138, 2: 1152, 3: 1146} | Time elapsed=49.71 mins | Score 2 +20
# Progress: 4619/5016 | accepted={0: 1164, 1: 1157, 2: 1152, 3: 1146} | Time elapsed=49.82 mins | Score 1 +19
# Progress: 4624/5016 | accepted={0: 1164, 1: 1157, 2: 1152, 3: 1151} | Time elapsed=49.93 mins | Score 3 +5
# Progress: 4624/5016 | accepted={0: 1164, 1: 1157, 2: 1152, 3: 1151} | Time elapsed=50.09 mins | Score 3 +0
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "To extract the materials from the vinegar, the experiment would need to specify the conditions for drying the materials, such as a sunny, warm place or a dark, cold place. The procedure should also detail the conditions for soaking the materials,
# Progress: 4948/5016 | accepted={0: 1238, 1: 1238, 2: 1246, 3: 1226} | Time elapsed=54.08 mins | Score 2 +24
# Progress: 4962/5016 | accepted={0: 1238, 1: 1238, 2: 1246, 3: 1240} | Time elapsed=54.32 mins | Score 3 +14
# Bad JSON from Claude. Retrying. (streak: 1 )
# ["The mRNA leaves the cell and gives its information to the tRNA, which then travels and delivers the message to another cell to be translated and help the body stay healthy, grow, and repair itself.", "The first additional step would be to measure t
# Progress: 4983/5016 | accepted={0: 1259, 1: 1238, 2: 1246, 3: 1240} | Time elapsed=54.66 mins | Score 0 +21
# Progress: 4990/5016 | accepted={0: 1259, 1: 1238, 2: 1246, 3: 1247} | Time elapsed=54.81 mins | Score 3 +7
# Progress: 5002/5016 | accepted={0: 1259, 1: 1250, 2: 1246, 3: 1247} | Time elapsed=54.99 mins | Score 1 +12
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "If she told the truth, she would hurt her aunt.",
# "In my opinion, the dark gray color would be the best choice for the dog house. The data shows that the dark gray had an average temperature of 48°C, which is not too hot or too cold for the dog. T
# Progress: 5009/5016 | accepted={0: 1259, 1: 1250, 2: 1253, 3: 1247} | Time elapsed=55.46 mins | Score 2 +7
# Progress: 5016/5016 | accepted={0: 1259, 1: 1250, 2: 1253, 3: 1254} | Time elapsed=55.63 mins | Score 3 +7
# Generation done. New rows created: 5016

# %%
file_new = pd.DataFrame(new_rows)

combined = pd.concat([file, file_new], ignore_index=True)

combined["EssayText"] = combined["EssayText"].map(clean_rows)
combined["type"] = combined["type"].fillna("").astype(str).str.strip().str.lower()

orig = combined[combined["type"] != "paraphrased"].copy()
para = combined[combined["type"] == "paraphrased"].copy()

orig["_normalise"] = orig["EssayText"].map(clean_rows).map(str.lower)
para["_normalise"] = para["EssayText"].map(clean_rows).map(str.lower)

para = para.drop_duplicates(subset=["Score2", "_normalise"], keep="first")

orig_keys = set(zip(orig["Score2"], orig["_normalise"]))
para = para[~para.apply(lambda r: (r["Score2"], r["_normalise"]) in orig_keys, axis=1)]

orig = orig.drop(columns=["_normalise"])
para = para.drop(columns=["_normalise"])

final_27000 = pd.concat([orig, para], ignore_index=True)

print("Total rows in dataset after augmenting to 22000: ", len(final_27000))
print(final_27000["Score2"].value_counts().sort_index())

#final check to see if there's no paraphrased dueps
paraRows = final_27000[final_27000["type"] == "paraphrased"].copy()

paraRows["_normalise"] = paraRows["EssayText"].map(clean_rows).map(str.lower)
dupe_para = paraRows.duplicated(subset=["Score2", "_normalise"], keep=False).sum()
print("Paraphrased duplicate rows involved:", dupe_para)
# Out:
# Total rows in dataset after augmenting to 22000:  27136
# Score2
# 0    6807
# 1    6803
# 2    6776
# 3    6750
# Name: count, dtype: int64
# Paraphrased duplicate rows involved: 0

# %%
folder = "/content/drive/MyDrive/Data Augmentation/Claude/claude_27000"
os.makedirs(folder,exist_ok=True)

# %%
savepath = "/content/drive/MyDrive/Data Augmentation/Claude/claude_27000"
outpath = f"{savepath}/augment_claude_27000_final.csv"
final_27000 = final_27000[["EssayText", "Score2", "type"]].copy()
final_27000.to_csv(outpath, index=False)
print("Saved:", outpath)
# Out:
# Saved: /content/drive/MyDrive/Data Augmentation/Claude/claude_27000/augment_claude_27000_final.csv
