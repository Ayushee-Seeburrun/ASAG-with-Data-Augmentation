# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushee-Seeburrun/ASAG-with-Data-Augmentation/blob/main/claude_22000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os,json,time, random
import pandas as pd
import requests
from google.colab import userdata

# %%
path = "/content/drive/MyDrive/Data Augmentation/Dataset Splits"
file = pd.read_csv(f"{path}/train_balanced_clean.csv")

# %%
import re, unicodedata
def clean_rows(s):
    s = str(s)
    s = unicodedata.normalize("NFKC", s)
    s = s.replace("\u00A0", " ")
    s = re.sub(r"\s+", " ", s).strip()
    return s

file["EssayText"] = file["EssayText"].map(clean_rows)
file["type"] = file["type"].fillna("").astype(str).str.strip().str.lower()

# %%
#to prioritise fairness and avoid bias towards any score
total = 22000
genperscore = total // 4

#unique counts per score using (Score2, normalized EssayText)
file["EssayText_norm"] = file["EssayText"].map(clean_rows)

uniqueScoreCount = (
    file.drop_duplicates(subset=["Score2", "EssayText_norm"])
        .groupby("Score2").size()
        .reindex([0,1,2,3], fill_value=0)
)

generateScore = (genperscore - uniqueScoreCount).clip(lower=0).astype(int)

print("Current original rows counts per score:", file["Score2"].value_counts().sort_index().to_dict())
print("Current unique counts per score:", uniqueScoreCount.to_dict())
print("Number of unique new paraphrases to be added per score:", generateScore.to_dict())
# Out:
# Current original rows counts per score: {0: 5424, 1: 4518, 2: 4194, 3: 3089}
# Current unique counts per score: {0: 5376, 1: 4465, 2: 4168, 3: 3089}
# Number of unique new paraphrases to be added per score: {0: 124, 1: 1035, 2: 1332, 3: 2411}

# %%
print("Sanity check (unique + to_generate):")
for s in [0,1,2,3]:
    print(s, uniqueScoreCount[s], "+", generateScore[s], "=", uniqueScoreCount[s] + generateScore[s])
# Out:
# Sanity check (unique + to_generate):
# 0 5376 + 124 = 5500
# 1 4465 + 1035 = 5500
# 2 4168 + 1332 = 5500
# 3 3089 + 2411 = 5500

# %%
#selecting all original rows to avoid claude learning from claude.
original = file[file["type"] != "paraphrased"].copy()

def strip_caret_p(text: str) -> str:
    return str(text).replace("^p", " ").replace("^P", " ")

score_anchors = {
    s: [strip_caret_p(t) for t in original[original["Score2"] == s]["EssayText"].tolist()]
    for s in [0, 1, 2, 3]
}
for s in score_anchors:
  print(f"Score {s} original anchors: ", len(score_anchors[s]))
# Out:
# Score 0 original anchors:  5424
# Score 1 original anchors:  4518
# Score 2 original anchors:  3225
# Score 3 original anchors:  598

# %%
#all the answers that already exist in the dataset
existing_data = set(zip(file["Score2"], file["EssayText_norm"].str.lower()))

#this function checks if a paraphrase is safe to accept , seen_batch tracks what has already been accepted within the current response from Claude
def new_phrase(score, text, seen_batch) :

  #claening the claude output
  text = clean_rows(text)
  #if text has same score and same normalized text ---> its a duplicate
  key = (score, text.lower())
  return(key not in existing_data) and (key not in seen_batch), text

# %%
#setting the static rules to apply prompt caching
static_sys = """
You are helping with ASAG data augmentation.
Task: Paraphrase student answers.
Rules:
-Keep the SAME meaning and the SAME level of correctness.
-Do not add or remove information.
-Do not reuse any 4 consecutive words from the original answer.
-Do not output labels like "Student answer: " or "Paraphrased answer:" or any commentary.
-Return only valid JSON(no markdown).
-Output must be a JSON array of strings (each string is only the paraphrased answer), same order as input.
-Escape any quotes inside the strings with backslash.
-Avoid repetitive sentence starters. Vary the opening sentences each time.
- DO NOT begin answers with phrases such as:
  "To replicate the experiment", "Based on the data", "The student's data indicates".
-DO NOT use lettered formatting like "a)" "b)" or symbols like "^p".
-DO NOT use numbered lists (e.g., "1.", "2.", "3."). Write as one natural paragraph (no list formatting), unless the original answer is a list.
-DO NOT start with: "The student", "The student's", "This answer", "The answer", "Based on", "To replicate".
-DO NOT refer to the response as a student's work (no "the student", no "the student's answer", no "The student responds").
-Write strictly in English.
-Write in a more natural tone, like a student answering an exam question.
"""

# %%
def dynamic_prompt(textlist):
  return(
      "Paraphrase the following student answers.\n Return only a valid JSON array of strings,same order.\n DO NOT add labels like 'student answer:' or 'paraphrased answer:'.\n" + json.dumps(textlist,ensure_ascii=False)
  )

# %%
claude_api_key = userdata.get('Claude_key')

# %%
def claude_call(prompt):
  resp= requests.post("https://api.anthropic.com/v1/messages",
      headers={
          "x-api-key":claude_api_key,
          "anthropic-version": "2023-06-01",
          "content-type": "application/json"
     },
      json={
          "model": "claude-3-haiku-20240307",
          "max_tokens": 2500,
          "system": [{
              "type":"text",
              "text": static_sys,
              "cache_control": {"type": "ephemeral"}
          }],
          "messages": [{
              "role":"user",
              "content": [{"type": "text", "text" : prompt}]
          }]
      },
  )
  if resp.status_code == 200:
    return resp.json()["content"][0]["text"]
  else:
    print("Claude API error: ", resp.status_code)
    print(resp.text[:300])
    return None

# %%
def parse_json_array(text):
    try:
        data = json.loads(text)
        if isinstance(data, list) and all(isinstance(x, str) for x in data):
            return data
        return None
    except:
        return None

# %%
#here we're tracking where we are in the anchor list of each score
anchor_in = {s: 0 for s in [0,1,2,3]}
for s in score_anchors :
   random.shuffle(score_anchors[s])   #randomly choosing the anchor order to avoid giving the same patterns to clsude


def next_anchor(score, k):
  pool = score_anchors[score]

  if not pool:
    return[]

  out = []
  for i in range(k):
    out.append(pool[anchor_in[score] % len(pool)])
    anchor_in[score] += 1

  return out

# %%
batch_size = 30

accepted_para = {0:0, 1:0, 2:0, 3:0}
new_rows = []

bad_json_streak = 0
startTime = time.time()
def print_progress(extra_note=""):
    elapsed = (time.time() - startTime) / 60
    totalAdded = sum(accepted_para.values())
    totalNeeded = int(generateScore.sum())
    print(
        f"Progress: {totalAdded}/{totalNeeded} | "
        f"accepted={accepted_para} | Time elapsed={elapsed:.2f} mins {extra_note}"
    )

#here it keeps generating paraphrases until the required number has been added for all scores
while sum(accepted_para.values()) < int(generateScore.sum()):


    remaining = {s: int(generateScore[s] - accepted_para[s]) for s in [0,1,2,3]}
    #here the scores completed are being removed and only those that still need augmentation are kept
    remaining = {s:r for s,r in remaining.items() if r > 0}

    #if all scores completed, the loop is exited
    if not remaining:
        break

    #pick the score with the biggesdt gap to fill
    score = max(remaining, key=remaining.get)

    #get anchors by cycling through the originals rows to avoid repeating the same anchors each time
    k = min(batch_size, len(score_anchors[score]))
    anchors = next_anchor(score, k)

    #it converts the anchor list -->  json-based prompt
    prompt = dynamic_prompt(anchors)
    #sends the request to Claude , returns a JSON array of paraphrases
    result = claude_call(prompt)

    if result is None:
        print("API failed. Retrying...")
        time.sleep(6)
        continue

    #converts the responses from Claude into a lsit
    paraphrases = parse_json_array(result)

    if paraphrases is None:
        bad_json_streak += 1
        print("Bad JSON from Claude. Retrying. (streak:", bad_json_streak, ")")
        print(result[:250])
        time.sleep(4)

        if bad_json_streak >= 10:
            print("Too many bad JSON responses. Stopping for safety.")
            break
        continue

    bad_json_streak = 0

    #this blocks dupes within the same CLaude response
    seen_batch = set()
    added = 0

    for para in paraphrases:
        if accepted_para[score] >= int(generateScore[score]):
            break
        if para is None:
            continue

        #cleaning the Claude output and checks for dupes
        ok, cleaned = new_phrase(score, para, seen_batch)
        if not ok:
            continue

        p = cleaned.lower()

        p0 = p.lstrip()
        if p0.startswith((
            "the student", "the student's",
            "this answer", "the answer",
            "based on", "to replicate"
        )):
          continue



        if "^p" in p:
            continue
        if p.startswith(("1.", "2.", "3.")):
            continue
        if "(a)" in p or "(b)" in p or p.startswith(("a)", "b)", "a.", "b.")):
            continue
        if cleaned.endswith((" to", " and", " or", " because", " but")):
            continue
        if len(cleaned) < 60:
            continue

        # accept
        new_rows.append({
            "EssayText": cleaned,
            "Score2": score,
            "type": "paraphrased"
        })

        #below ensures that the future batches dont introduce same paraphrases again
        existing_data.add((score, clean_rows(cleaned)))
        seen_batch.add((score, clean_rows(cleaned)))


        accepted_para[score] += 1
        added += 1

    print_progress(extra_note=f"| Score {score} +{added}")
    time.sleep(1.0)

print("Generation done. New rows created:", len(new_rows))
# Out:
# Progress: 10/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 10} | Time elapsed=0.15 mins | Score 3 +10
# Progress: 21/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 21} | Time elapsed=0.30 mins | Score 3 +11
# Progress: 36/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 36} | Time elapsed=0.47 mins | Score 3 +15
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "Polymer plastic B demonstrates the greatest stretchability, as it has the longest length in both trials. To improve the experiment, the student could have specified the amount of weight added to each plastic sample, and repeated the trials more th
# Progress: 50/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 50} | Time elapsed=0.90 mins | Score 3 +14
# Progress: 72/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 72} | Time elapsed=1.09 mins | Score 3 +22
# Progress: 82/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 82} | Time elapsed=1.32 mins | Score 3 +10
# Progress: 87/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 87} | Time elapsed=1.45 mins | Score 3 +5
# Progress: 101/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 101} | Time elapsed=1.65 mins | Score 3 +14
# Progress: 113/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 113} | Time elapsed=1.81 mins | Score 3 +12
# Progress: 120/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 120} | Time elapsed=1.95 mins | Score 3 +7
# Progress: 135/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 135} | Time elapsed=2.22 mins | Score 3 +15
# Progress: 155/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 155} | Time elapsed=2.44 mins | Score 3 +20
# Progress: 165/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 165} | Time elapsed=2.64 mins | Score 3 +10
# Progress: 174/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 174} | Time elapsed=2.86 mins | Score 3 +9
# Progress: 193/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 193} | Time elapsed=3.02 mins | Score 3 +19
# Progress: 208/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 208} | Time elapsed=3.25 mins | Score 3 +15
# Progress: 223/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 223} | Time elapsed=3.46 mins | Score 3 +15
# Progress: 240/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 240} | Time elapsed=3.62 mins | Score 3 +17
# Progress: 252/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 252} | Time elapsed=3.78 mins | Score 3 +12
# Progress: 273/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 273} | Time elapsed=3.94 mins | Score 3 +21
# Progress: 288/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 288} | Time elapsed=4.09 mins | Score 3 +15
# Progress: 303/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 303} | Time elapsed=4.36 mins | Score 3 +15
# Progress: 312/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 312} | Time elapsed=4.51 mins | Score 3 +9
# Progress: 325/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 325} | Time elapsed=4.72 mins | Score 3 +13
# Progress: 345/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 345} | Time elapsed=4.89 mins | Score 3 +20
# Progress: 348/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 348} | Time elapsed=4.97 mins | Score 3 +3
# Progress: 354/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 354} | Time elapsed=5.16 mins | Score 3 +6
# Progress: 367/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 367} | Time elapsed=5.38 mins | Score 3 +13
# Progress: 380/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 380} | Time elapsed=5.63 mins | Score 3 +13
# Progress: 393/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 393} | Time elapsed=5.84 mins | Score 3 +13
# Progress: 399/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 399} | Time elapsed=5.92 mins | Score 3 +6
# Progress: 417/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 417} | Time elapsed=6.05 mins | Score 3 +18
# Progress: 435/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 435} | Time elapsed=6.23 mins | Score 3 +18
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The data indicates that plastic type B has the highest stretchability, stretching 22 and 23mm, the furthest of the four plastics. In contrast, plastic type A is the least stretchable, only stretching 10 and 12mm. To improve the validity, the exper
# Progress: 443/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 443} | Time elapsed=6.71 mins | Score 3 +8
# Progress: 460/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 460} | Time elapsed=6.90 mins | Score 3 +17
# Progress: 481/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 481} | Time elapsed=7.10 mins | Score 3 +21
# Progress: 502/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 502} | Time elapsed=7.24 mins | Score 3 +21
# Progress: 517/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 517} | Time elapsed=7.46 mins | Score 3 +15
# Progress: 526/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 526} | Time elapsed=7.79 mins | Score 3 +9
# Progress: 536/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 536} | Time elapsed=7.91 mins | Score 3 +10
# Progress: 553/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 553} | Time elapsed=8.08 mins | Score 3 +17
# Progress: 563/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 563} | Time elapsed=8.35 mins | Score 3 +10
# Progress: 575/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 575} | Time elapsed=8.52 mins | Score 3 +12
# Progress: 589/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 589} | Time elapsed=8.67 mins | Score 3 +14
# Progress: 598/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 598} | Time elapsed=8.81 mins | Score 3 +9
# Progress: 603/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 603} | Time elapsed=8.92 mins | Score 3 +5
# Progress: 617/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 617} | Time elapsed=9.19 mins | Score 3 +14
# Progress: 629/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 629} | Time elapsed=9.41 mins | Score 3 +12
# Progress: 637/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 637} | Time elapsed=9.51 mins | Score 3 +8
# Progress: 655/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 655} | Time elapsed=9.70 mins | Score 3 +18
# Progress: 666/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 666} | Time elapsed=9.91 mins | Score 3 +11
# Progress: 672/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 672} | Time elapsed=10.00 mins | Score 3 +6
# Progress: 680/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 680} | Time elapsed=10.20 mins | Score 3 +8
# Progress: 687/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 687} | Time elapsed=10.32 mins | Score 3 +7
# Progress: 702/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 702} | Time elapsed=10.52 mins | Score 3 +15
# Progress: 714/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 714} | Time elapsed=10.67 mins | Score 3 +12
# Progress: 729/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 729} | Time elapsed=10.82 mins | Score 3 +15
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "One could reproduce this experiment by determining the mass difference of the materials after the process. Additionally, the types of materials used should be specified. The amount and kind of vinegar utilized is also crucial information.",
# "To re
# Progress: 741/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 741} | Time elapsed=11.21 mins | Score 3 +12
# Progress: 756/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 756} | Time elapsed=11.43 mins | Score 3 +15
# Progress: 766/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 766} | Time elapsed=11.57 mins | Score 3 +10
# Progress: 774/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 774} | Time elapsed=11.79 mins | Score 3 +8
# Progress: 790/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 790} | Time elapsed=12.08 mins | Score 3 +16
# Progress: 796/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 796} | Time elapsed=12.15 mins | Score 3 +6
# Progress: 808/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 808} | Time elapsed=12.27 mins | Score 3 +12
# Progress: 816/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 816} | Time elapsed=12.44 mins | Score 3 +8
# Progress: 828/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 828} | Time elapsed=12.63 mins | Score 3 +12
# Progress: 837/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 837} | Time elapsed=12.89 mins | Score 3 +9
# Progress: 843/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 843} | Time elapsed=12.96 mins | Score 3 +6
# Progress: 849/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 849} | Time elapsed=13.06 mins | Score 3 +6
# Progress: 861/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 861} | Time elapsed=13.26 mins | Score 3 +12
# Progress: 876/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 876} | Time elapsed=13.42 mins | Score 3 +15
# Progress: 886/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 886} | Time elapsed=13.65 mins | Score 3 +10
# Progress: 897/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 897} | Time elapsed=13.83 mins | Score 3 +11
# Progress: 910/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 910} | Time elapsed=14.01 mins | Score 3 +13
# Progress: 920/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 920} | Time elapsed=14.18 mins | Score 3 +10
# Progress: 936/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 936} | Time elapsed=14.36 mins | Score 3 +16
# Progress: 944/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 944} | Time elapsed=14.53 mins | Score 3 +8
# Progress: 958/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 958} | Time elapsed=14.69 mins | Score 3 +14
# Progress: 975/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 975} | Time elapsed=14.92 mins | Score 3 +17
# Progress: 985/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 985} | Time elapsed=15.07 mins | Score 3 +10
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The data indicates that plastic type B exhibited the greatest stretchability, with a difference of 2 to 3 mm compared to type D, which had the second highest stretchability. Type C showed a difference of 10-8 mm compared to type B, while type A ha
# Progress: 988/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 988} | Time elapsed=15.42 mins | Score 3 +3
# Progress: 1006/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 1006} | Time elapsed=15.68 mins | Score 3 +18
# Progress: 1015/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 1015} | Time elapsed=15.85 mins | Score 3 +9
# Progress: 1021/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 1021} | Time elapsed=16.04 mins | Score 3 +6
# Progress: 1035/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 1035} | Time elapsed=16.22 mins | Score 3 +14
# Progress: 1043/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 1043} | Time elapsed=16.41 mins | Score 3 +8
# Progress: 1057/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 1057} | Time elapsed=16.55 mins | Score 3 +14
# Progress: 1078/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 1078} | Time elapsed=16.75 mins | Score 3 +21
# Progress: 1090/4902 | accepted={0: 0, 1: 0, 2: 0, 3: 1090} | Time elapsed=16.98 mins | Score 3 +12
# Progress: 1110/4902 | accepted={0: 0, 1: 0, 2: 20, 3: 1090} | Time elapsed=17.16 mins | Score 2 +20
# Progress: 1123/4902 | accepted={0: 0, 1: 0, 2: 20, 3: 1103} | Time elapsed=17.29 mins | Score 3 +13
# Progress: 1146/4902 | accepted={0: 0, 1: 0, 2: 43, 3: 1103} | Time elapsed=17.47 mins | Score 2 +23
# Progress: 1160/4902 | accepted={0: 0, 1: 0, 2: 43, 3: 1117} | Time elapsed=17.64 mins | Score 3 +14
# Progress: 1170/4902 | accepted={0: 0, 1: 0, 2: 43, 3: 1127} | Time elapsed=17.76 mins | Score 3 +10
# Progress: 1196/4902 | accepted={0: 0, 1: 0, 2: 69, 3: 1127} | Time elapsed=18.00 mins | Score 2 +26
# Progress: 1211/4902 | accepted={0: 0, 1: 0, 2: 69, 3: 1142} | Time elapsed=18.17 mins | Score 3 +15
# Progress: 1219/4902 | accepted={0: 0, 1: 0, 2: 69, 3: 1150} | Time elapsed=18.28 mins | Score 3 +8
# Progress: 1238/4902 | accepted={0: 0, 1: 0, 2: 88, 3: 1150} | Time elapsed=18.42 mins | Score 2 +19
# Progress: 1255/4902 | accepted={0: 0, 1: 0, 2: 88, 3: 1167} | Time elapsed=18.59 mins | Score 3 +17
# Progress: 1278/4902 | accepted={0: 0, 1: 0, 2: 111, 3: 1167} | Time elapsed=18.76 mins | Score 2 +23
# Progress: 1291/4902 | accepted={0: 0, 1: 0, 2: 111, 3: 1180} | Time elapsed=18.86 mins | Score 3 +13
# Progress: 1301/4902 | accepted={0: 0, 1: 0, 2: 111, 3: 1190} | Time elapsed=19.03 mins | Score 3 +10
# Progress: 1321/4902 | accepted={0: 0, 1: 0, 2: 131, 3: 1190} | Time elapsed=19.18 mins | Score 2 +20
# Progress: 1337/4902 | accepted={0: 0, 1: 0, 2: 131, 3: 1206} | Time elapsed=19.32 mins | Score 3 +16
# Progress: 1350/4902 | accepted={0: 0, 1: 0, 2: 131, 3: 1219} | Time elapsed=19.52 mins | Score 3 +13
# Progress: 1368/4902 | accepted={0: 0, 1: 0, 2: 149, 3: 1219} | Time elapsed=19.68 mins | Score 2 +18
# Progress: 1381/4902 | accepted={0: 0, 1: 0, 2: 149, 3: 1232} | Time elapsed=19.92 mins | Score 3 +13
# Progress: 1402/4902 | accepted={0: 0, 1: 0, 2: 170, 3: 1232} | Time elapsed=20.09 mins | Score 2 +21
# Progress: 1412/4902 | accepted={0: 0, 1: 0, 2: 170, 3: 1242} | Time elapsed=20.19 mins | Score 3 +10
# Progress: 1430/4902 | accepted={0: 0, 1: 0, 2: 170, 3: 1260} | Time elapsed=20.36 mins | Score 3 +18
# Progress: 1455/4902 | accepted={0: 0, 1: 0, 2: 195, 3: 1260} | Time elapsed=20.54 mins | Score 2 +25
# Progress: 1468/4902 | accepted={0: 0, 1: 0, 2: 195, 3: 1273} | Time elapsed=20.75 mins | Score 3 +13
# Progress: 1477/4902 | accepted={0: 0, 1: 0, 2: 195, 3: 1282} | Time elapsed=20.92 mins | Score 3 +9
# Progress: 1499/4902 | accepted={0: 0, 1: 0, 2: 217, 3: 1282} | Time elapsed=21.12 mins | Score 2 +22
# Progress: 1514/4902 | accepted={0: 0, 1: 0, 2: 217, 3: 1297} | Time elapsed=21.29 mins | Score 3 +15
# Progress: 1539/4902 | accepted={0: 0, 1: 0, 2: 242, 3: 1297} | Time elapsed=21.43 mins | Score 2 +25
# Progress: 1548/4902 | accepted={0: 0, 1: 0, 2: 242, 3: 1306} | Time elapsed=21.59 mins | Score 3 +9
# Progress: 1554/4902 | accepted={0: 0, 1: 0, 2: 242, 3: 1312} | Time elapsed=21.74 mins | Score 3 +6
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "Based on the data, plastic type B appears to have the greatest stretchability, stretching 22mm in trial 1 and 23mm in trial 2, which exceeds the stretching observed for plastics A, C, and D. Plastic A only stretched 10mm and 12mm in the two trials
# Progress: 1563/4902 | accepted={0: 0, 1: 0, 2: 242, 3: 1321} | Time elapsed=22.16 mins | Score 3 +9
# Progress: 1585/4902 | accepted={0: 0, 1: 0, 2: 264, 3: 1321} | Time elapsed=22.42 mins | Score 2 +22
# Progress: 1594/4902 | accepted={0: 0, 1: 0, 2: 264, 3: 1330} | Time elapsed=22.56 mins | Score 3 +9
# Progress: 1614/4902 | accepted={0: 0, 1: 0, 2: 264, 3: 1350} | Time elapsed=22.76 mins | Score 3 +20
# Progress: 1635/4902 | accepted={0: 0, 1: 0, 2: 285, 3: 1350} | Time elapsed=22.93 mins | Score 2 +21
# Progress: 1644/4902 | accepted={0: 0, 1: 0, 2: 285, 3: 1359} | Time elapsed=23.14 mins | Score 3 +9
# Progress: 1651/4902 | accepted={0: 0, 1: 0, 2: 285, 3: 1366} | Time elapsed=23.24 mins | Score 3 +7
# Progress: 1674/4902 | accepted={0: 0, 1: 0, 2: 308, 3: 1366} | Time elapsed=23.43 mins | Score 2 +23
# Progress: 1691/4902 | accepted={0: 0, 1: 0, 2: 308, 3: 1383} | Time elapsed=23.54 mins | Score 3 +17
# Progress: 1714/4902 | accepted={0: 0, 1: 23, 2: 308, 3: 1383} | Time elapsed=23.67 mins | Score 1 +23
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The data indicates that plastic type B exhibited the greatest stretchability, stretching an average of 22.5mm compared to the other plastic types. To improve the experiment, the students could have specified the weight added and ensured the same s
# Progress: 1728/4902 | accepted={0: 0, 1: 23, 2: 308, 3: 1397} | Time elapsed=24.09 mins | Score 3 +14
# Progress: 1728/4902 | accepted={0: 0, 1: 23, 2: 308, 3: 1397} | Time elapsed=24.28 mins | Score 2 +0
# Progress: 1753/4902 | accepted={0: 0, 1: 23, 2: 333, 3: 1397} | Time elapsed=24.49 mins | Score 2 +25
# Progress: 1761/4902 | accepted={0: 0, 1: 23, 2: 333, 3: 1405} | Time elapsed=24.70 mins | Score 3 +8
# Progress: 1786/4902 | accepted={0: 0, 1: 48, 2: 333, 3: 1405} | Time elapsed=24.90 mins | Score 1 +25
# Progress: 1804/4902 | accepted={0: 0, 1: 48, 2: 333, 3: 1423} | Time elapsed=25.06 mins | Score 3 +18
# Progress: 1827/4902 | accepted={0: 0, 1: 48, 2: 356, 3: 1423} | Time elapsed=25.28 mins | Score 2 +23
# Progress: 1838/4902 | accepted={0: 0, 1: 48, 2: 356, 3: 1434} | Time elapsed=25.47 mins | Score 3 +11
# Progress: 1864/4902 | accepted={0: 0, 1: 74, 2: 356, 3: 1434} | Time elapsed=25.63 mins | Score 1 +26
# Progress: 1872/4902 | accepted={0: 0, 1: 74, 2: 356, 3: 1442} | Time elapsed=25.86 mins | Score 3 +8
# Progress: 1899/4902 | accepted={0: 0, 1: 74, 2: 383, 3: 1442} | Time elapsed=26.08 mins | Score 2 +27
# Progress: 1910/4902 | accepted={0: 0, 1: 74, 2: 383, 3: 1453} | Time elapsed=26.20 mins | Score 3 +11
# Progress: 1931/4902 | accepted={0: 0, 1: 95, 2: 383, 3: 1453} | Time elapsed=26.31 mins | Score 1 +21
# Progress: 1941/4902 | accepted={0: 0, 1: 95, 2: 383, 3: 1463} | Time elapsed=26.49 mins | Score 3 +10
# Progress: 1965/4902 | accepted={0: 0, 1: 95, 2: 407, 3: 1463} | Time elapsed=26.67 mins | Score 2 +24
# Progress: 1979/4902 | accepted={0: 0, 1: 95, 2: 407, 3: 1477} | Time elapsed=26.86 mins | Score 3 +14
# Progress: 2006/4902 | accepted={0: 0, 1: 122, 2: 407, 3: 1477} | Time elapsed=27.02 mins | Score 1 +27
# Progress: 2015/4902 | accepted={0: 0, 1: 122, 2: 407, 3: 1486} | Time elapsed=27.15 mins | Score 3 +9
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The passage initially defines what space junk is - satellites orbiting without control. It then delves into the topic of crashing satellites, known as the 'Crash Course' section. Finally, it explores the issue of small space debris, referred to as
# Progress: 2042/4902 | accepted={0: 0, 1: 122, 2: 434, 3: 1486} | Time elapsed=27.62 mins | Score 2 +27
# Progress: 2055/4902 | accepted={0: 0, 1: 122, 2: 434, 3: 1499} | Time elapsed=27.84 mins | Score 3 +13
# Progress: 2078/4902 | accepted={0: 0, 1: 145, 2: 434, 3: 1499} | Time elapsed=28.00 mins | Score 1 +23
# Progress: 2087/4902 | accepted={0: 0, 1: 145, 2: 434, 3: 1508} | Time elapsed=28.24 mins | Score 3 +9
# Progress: 2097/4902 | accepted={0: 0, 1: 145, 2: 434, 3: 1518} | Time elapsed=28.38 mins | Score 3 +10
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The color white would be ideal for a dog house as it absorbs the least heat compared to other colors like black, dark grey, or light grey based on the experiment's findings.",
# "Pandas and koalas are both dietary specialists, relying on a single fo
# Progress: 2114/4902 | accepted={0: 0, 1: 145, 2: 451, 3: 1518} | Time elapsed=28.68 mins | Score 2 +17
# Progress: 2132/4902 | accepted={0: 0, 1: 145, 2: 451, 3: 1536} | Time elapsed=28.87 mins | Score 3 +18
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "Pandas and koalas are alike as they each have a very limited diet, feeding almost exclusively on one type of food. They contrast with pythons, which are generalist predators that can consume a wide variety of prey.",
# "One process is cell diffusion
# Progress: 2158/4902 | accepted={0: 0, 1: 171, 2: 451, 3: 1536} | Time elapsed=29.23 mins | Score 1 +26
# Progress: 2184/4902 | accepted={0: 0, 1: 171, 2: 477, 3: 1536} | Time elapsed=29.40 mins | Score 2 +26
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The plastic A appears to have stretched the least among all the plastics used. Plastic B, on the other hand, stretched the most. Plastic A's better performance can be attributed to its superior quality compared to plastic B. To improve the experim
# Progress: 2192/4902 | accepted={0: 0, 1: 171, 2: 477, 3: 1544} | Time elapsed=29.76 mins | Score 3 +8
# Progress: 2207/4902 | accepted={0: 0, 1: 171, 2: 477, 3: 1559} | Time elapsed=29.95 mins | Score 3 +15
# Progress: 2231/4902 | accepted={0: 0, 1: 195, 2: 477, 3: 1559} | Time elapsed=30.14 mins | Score 1 +24
# Progress: 2255/4902 | accepted={0: 0, 1: 195, 2: 501, 3: 1559} | Time elapsed=30.34 mins | Score 2 +24
# Progress: 2267/4902 | accepted={0: 0, 1: 195, 2: 501, 3: 1571} | Time elapsed=30.49 mins | Score 3 +12
# Progress: 2285/4902 | accepted={0: 0, 1: 213, 2: 501, 3: 1571} | Time elapsed=30.61 mins | Score 1 +18
# Progress: 2300/4902 | accepted={0: 0, 1: 213, 2: 501, 3: 1586} | Time elapsed=30.74 mins | Score 3 +15
# Progress: 2321/4902 | accepted={0: 0, 1: 213, 2: 522, 3: 1586} | Time elapsed=31.00 mins | Score 2 +21
# Progress: 2336/4902 | accepted={0: 0, 1: 213, 2: 522, 3: 1601} | Time elapsed=31.09 mins | Score 3 +15
# Progress: 2361/4902 | accepted={0: 0, 1: 238, 2: 522, 3: 1601} | Time elapsed=31.24 mins | Score 1 +25
# Progress: 2378/4902 | accepted={0: 0, 1: 238, 2: 539, 3: 1601} | Time elapsed=31.43 mins | Score 2 +17
# Progress: 2395/4902 | accepted={0: 0, 1: 238, 2: 539, 3: 1618} | Time elapsed=31.62 mins | Score 3 +17
# Progress: 2424/4902 | accepted={0: 0, 1: 267, 2: 539, 3: 1618} | Time elapsed=31.86 mins | Score 1 +29
# Progress: 2447/4902 | accepted={0: 0, 1: 267, 2: 562, 3: 1618} | Time elapsed=32.03 mins | Score 2 +23
# Progress: 2457/4902 | accepted={0: 0, 1: 267, 2: 562, 3: 1628} | Time elapsed=32.26 mins | Score 3 +10
# Progress: 2472/4902 | accepted={0: 0, 1: 267, 2: 562, 3: 1643} | Time elapsed=32.44 mins | Score 3 +15
# Progress: 2492/4902 | accepted={0: 0, 1: 267, 2: 582, 3: 1643} | Time elapsed=32.58 mins | Score 2 +20
# Progress: 2518/4902 | accepted={0: 0, 1: 293, 2: 582, 3: 1643} | Time elapsed=32.74 mins | Score 1 +26
# Progress: 2531/4902 | accepted={0: 0, 1: 293, 2: 582, 3: 1656} | Time elapsed=32.89 mins | Score 3 +13
# Progress: 2536/4902 | accepted={0: 0, 1: 293, 2: 582, 3: 1661} | Time elapsed=33.03 mins | Score 3 +5
# Progress: 2561/4902 | accepted={0: 0, 1: 293, 2: 607, 3: 1661} | Time elapsed=33.32 mins | Score 2 +25
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "To replicate the experiment, you would need to know the specific amounts of vinegar used in each step. The temperature at which the samples were kept for 24 hours is also crucial information. Additionally, the exact names and descriptions of the 4
# Progress: 2574/4902 | accepted={0: 0, 1: 293, 2: 607, 3: 1674} | Time elapsed=33.83 mins | Score 3 +13
# Progress: 2598/4902 | accepted={0: 0, 1: 317, 2: 607, 3: 1674} | Time elapsed=33.99 mins | Score 1 +24
# Progress: 2618/4902 | accepted={0: 0, 1: 317, 2: 607, 3: 1694} | Time elapsed=34.16 mins | Score 3 +20
# Progress: 2642/4902 | accepted={0: 0, 1: 317, 2: 631, 3: 1694} | Time elapsed=34.38 mins | Score 2 +24
# Progress: 2669/4902 | accepted={0: 0, 1: 344, 2: 631, 3: 1694} | Time elapsed=34.56 mins | Score 1 +27
# Progress: 2679/4902 | accepted={0: 0, 1: 344, 2: 631, 3: 1704} | Time elapsed=34.77 mins | Score 3 +10
# Progress: 2687/4902 | accepted={0: 0, 1: 344, 2: 631, 3: 1712} | Time elapsed=34.88 mins | Score 3 +8
# Progress: 2714/4902 | accepted={0: 0, 1: 344, 2: 658, 3: 1712} | Time elapsed=35.08 mins | Score 2 +27
# Progress: 2723/4902 | accepted={0: 0, 1: 344, 2: 658, 3: 1721} | Time elapsed=35.30 mins | Score 3 +9
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The word \"invasive\" is used to show the differing perspectives on pet reptiles. Some see them as exciting, while others view them as threatening human habitats. The article also discusses specific examples of pythons found in unexpected places,
# Progress: 2742/4902 | accepted={0: 0, 1: 363, 2: 658, 3: 1721} | Time elapsed=35.66 mins | Score 1 +19
# Progress: 2758/4902 | accepted={0: 0, 1: 363, 2: 658, 3: 1737} | Time elapsed=35.93 mins | Score 3 +16
# Progress: 2776/4902 | accepted={0: 0, 1: 363, 2: 676, 3: 1737} | Time elapsed=36.11 mins | Score 2 +18
# Progress: 2784/4902 | accepted={0: 0, 1: 363, 2: 676, 3: 1745} | Time elapsed=36.19 mins | Score 3 +8
# Progress: 2804/4902 | accepted={0: 0, 1: 383, 2: 676, 3: 1745} | Time elapsed=36.32 mins | Score 1 +20
# Progress: 2818/4902 | accepted={0: 0, 1: 383, 2: 676, 3: 1759} | Time elapsed=36.52 mins | Score 3 +14
# Progress: 2843/4902 | accepted={0: 0, 1: 383, 2: 701, 3: 1759} | Time elapsed=36.72 mins | Score 2 +25
# Progress: 2871/4902 | accepted={0: 0, 1: 411, 2: 701, 3: 1759} | Time elapsed=36.91 mins | Score 1 +28
# Progress: 2880/4902 | accepted={0: 0, 1: 411, 2: 701, 3: 1768} | Time elapsed=37.10 mins | Score 3 +9
# Progress: 2886/4902 | accepted={0: 0, 1: 411, 2: 701, 3: 1774} | Time elapsed=37.19 mins | Score 3 +6
# Progress: 2898/4902 | accepted={0: 0, 1: 411, 2: 701, 3: 1786} | Time elapsed=37.45 mins | Score 3 +12
# Progress: 2925/4902 | accepted={0: 0, 1: 411, 2: 728, 3: 1786} | Time elapsed=37.71 mins | Score 2 +27
# Progress: 2933/4902 | accepted={0: 0, 1: 411, 2: 728, 3: 1794} | Time elapsed=37.82 mins | Score 3 +8
# Progress: 2933/4902 | accepted={0: 0, 1: 411, 2: 728, 3: 1794} | Time elapsed=37.97 mins | Score 1 +0
# Progress: 2957/4902 | accepted={0: 0, 1: 435, 2: 728, 3: 1794} | Time elapsed=38.11 mins | Score 1 +24
# Progress: 2975/4902 | accepted={0: 0, 1: 435, 2: 728, 3: 1812} | Time elapsed=38.22 mins | Score 3 +18
# Progress: 3000/4902 | accepted={0: 0, 1: 435, 2: 753, 3: 1812} | Time elapsed=38.42 mins | Score 2 +25
# Progress: 3025/4902 | accepted={0: 0, 1: 460, 2: 753, 3: 1812} | Time elapsed=38.54 mins | Score 1 +25
# Progress: 3042/4902 | accepted={0: 0, 1: 460, 2: 753, 3: 1829} | Time elapsed=38.77 mins | Score 3 +17
# Progress: 3057/4902 | accepted={0: 0, 1: 460, 2: 753, 3: 1844} | Time elapsed=38.89 mins | Score 3 +15
# Progress: 3084/4902 | accepted={0: 0, 1: 460, 2: 780, 3: 1844} | Time elapsed=39.12 mins | Score 2 +27
# Progress: 3112/4902 | accepted={0: 0, 1: 488, 2: 780, 3: 1844} | Time elapsed=39.32 mins | Score 1 +28
# Progress: 3123/4902 | accepted={0: 0, 1: 488, 2: 780, 3: 1855} | Time elapsed=39.55 mins | Score 3 +11
# Progress: 3142/4902 | accepted={0: 0, 1: 488, 2: 780, 3: 1874} | Time elapsed=39.76 mins | Score 3 +19
# Progress: 3164/4902 | accepted={0: 0, 1: 488, 2: 802, 3: 1874} | Time elapsed=39.90 mins | Score 2 +22
# Progress: 3187/4902 | accepted={0: 0, 1: 511, 2: 802, 3: 1874} | Time elapsed=40.10 mins | Score 1 +23
# Progress: 3204/4902 | accepted={0: 0, 1: 511, 2: 802, 3: 1891} | Time elapsed=40.35 mins | Score 3 +17
# Progress: 3229/4902 | accepted={0: 0, 1: 511, 2: 827, 3: 1891} | Time elapsed=40.58 mins | Score 2 +25
# Progress: 3254/4902 | accepted={0: 0, 1: 536, 2: 827, 3: 1891} | Time elapsed=40.73 mins | Score 1 +25
# Progress: 3265/4902 | accepted={0: 0, 1: 536, 2: 827, 3: 1902} | Time elapsed=40.93 mins | Score 3 +11
# Progress: 3272/4902 | accepted={0: 0, 1: 536, 2: 827, 3: 1909} | Time elapsed=41.12 mins | Score 3 +7
# Progress: 3290/4902 | accepted={0: 0, 1: 536, 2: 845, 3: 1909} | Time elapsed=41.24 mins | Score 2 +18
# Progress: 3303/4902 | accepted={0: 0, 1: 536, 2: 845, 3: 1922} | Time elapsed=41.46 mins | Score 3 +13
# Progress: 3332/4902 | accepted={0: 0, 1: 565, 2: 845, 3: 1922} | Time elapsed=41.61 mins | Score 1 +29
# Progress: 3348/4902 | accepted={0: 0, 1: 565, 2: 845, 3: 1938} | Time elapsed=41.79 mins | Score 3 +16
# Progress: 3374/4902 | accepted={0: 0, 1: 565, 2: 871, 3: 1938} | Time elapsed=42.01 mins | Score 2 +26
# Progress: 3384/4902 | accepted={0: 0, 1: 565, 2: 871, 3: 1948} | Time elapsed=42.14 mins | Score 3 +10
# Progress: 3409/4902 | accepted={0: 0, 1: 590, 2: 871, 3: 1948} | Time elapsed=42.32 mins | Score 1 +25
# Progress: 3423/4902 | accepted={0: 0, 1: 590, 2: 871, 3: 1962} | Time elapsed=42.49 mins | Score 3 +14
# Progress: 3442/4902 | accepted={0: 0, 1: 590, 2: 890, 3: 1962} | Time elapsed=42.62 mins | Score 2 +19
# Progress: 3454/4902 | accepted={0: 0, 1: 590, 2: 890, 3: 1974} | Time elapsed=42.75 mins | Score 3 +12
# Progress: 3481/4902 | accepted={0: 0, 1: 617, 2: 890, 3: 1974} | Time elapsed=42.96 mins | Score 1 +27
# Progress: 3504/4902 | accepted={0: 0, 1: 617, 2: 913, 3: 1974} | Time elapsed=43.12 mins | Score 2 +23
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The mRNA makes its way to a ribosome, where the code on it will be translated into the sequence of amino acids needed to construct a protein. The ribosome combines with rRNA to help chain the amino acids together into a polypeptide chain. tRNA fin
# Progress: 3514/4902 | accepted={0: 0, 1: 617, 2: 913, 3: 1984} | Time elapsed=43.69 mins | Score 3 +10
# Progress: 3534/4902 | accepted={0: 0, 1: 617, 2: 913, 3: 2004} | Time elapsed=43.82 mins | Score 3 +20
# Progress: 3560/4902 | accepted={0: 0, 1: 617, 2: 939, 3: 2004} | Time elapsed=44.07 mins | Score 2 +26
# Progress: 3587/4902 | accepted={0: 0, 1: 644, 2: 939, 3: 2004} | Time elapsed=44.23 mins | Score 1 +27
# Progress: 3599/4902 | accepted={0: 0, 1: 644, 2: 939, 3: 2016} | Time elapsed=44.46 mins | Score 3 +12
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "Based on the data, plastic type B stretched the most, with the bags stretching around 1-2 mm in both trials compared to their initial length. The student could have improved the experiment by showing the initial length of the bags and specifying t
# Progress: 3607/4902 | accepted={0: 0, 1: 644, 2: 939, 3: 2024} | Time elapsed=44.90 mins | Score 3 +8
# Progress: 3634/4902 | accepted={0: 0, 1: 644, 2: 966, 3: 2024} | Time elapsed=45.15 mins | Score 2 +27
# Progress: 3663/4902 | accepted={0: 0, 1: 673, 2: 966, 3: 2024} | Time elapsed=45.36 mins | Score 1 +29
# Progress: 3678/4902 | accepted={0: 0, 1: 673, 2: 966, 3: 2039} | Time elapsed=45.60 mins | Score 3 +15
# Progress: 3691/4902 | accepted={0: 0, 1: 673, 2: 966, 3: 2052} | Time elapsed=45.85 mins | Score 3 +13
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "Cells use their selective membranes to control what enters and exits the cell. They employ active transport, which moves substances against the concentration gradient and requires energy. They also use passive transport, which moves substances dow
# Progress: 3718/4902 | accepted={0: 0, 1: 673, 2: 993, 3: 2052} | Time elapsed=46.38 mins | Score 2 +27
# Progress: 3740/4902 | accepted={0: 0, 1: 695, 2: 993, 3: 2052} | Time elapsed=46.52 mins | Score 1 +22
# Progress: 3756/4902 | accepted={0: 0, 1: 695, 2: 993, 3: 2068} | Time elapsed=46.65 mins | Score 3 +16
# Progress: 3763/4902 | accepted={0: 0, 1: 695, 2: 993, 3: 2075} | Time elapsed=46.74 mins | Score 3 +7
# Progress: 3791/4902 | accepted={0: 0, 1: 723, 2: 993, 3: 2075} | Time elapsed=46.93 mins | Score 1 +28
# Progress: 3818/4902 | accepted={0: 0, 1: 723, 2: 1020, 3: 2075} | Time elapsed=47.15 mins | Score 2 +27
# Progress: 3828/4902 | accepted={0: 0, 1: 723, 2: 1020, 3: 2085} | Time elapsed=47.35 mins | Score 3 +10
# Progress: 3843/4902 | accepted={0: 0, 1: 723, 2: 1020, 3: 2100} | Time elapsed=47.54 mins | Score 3 +15
# Bad JSON from Claude. Retrying. (streak: 1 )
# ["According to the article, the significance of the word 'invasive' is substantial as it is frequently used throughout the text. The article indicates that the term 'invasive' refers to creatures like snakes or pythons that are invading our country a
# Progress: 3866/4902 | accepted={0: 0, 1: 746, 2: 1020, 3: 2100} | Time elapsed=47.90 mins | Score 1 +23
# Progress: 3889/4902 | accepted={0: 0, 1: 746, 2: 1043, 3: 2100} | Time elapsed=48.10 mins | Score 2 +23
# Progress: 3905/4902 | accepted={0: 0, 1: 746, 2: 1043, 3: 2116} | Time elapsed=48.31 mins | Score 3 +16
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The data indicates that type B polymer plastic stretched the farthest. To improve the experiment, the students could have added more trials and ensured that in step 2, all the plastic samples changed freely down the side of the table evenly by mea
# Progress: 3913/4902 | accepted={0: 0, 1: 746, 2: 1043, 3: 2124} | Time elapsed=48.72 mins | Score 3 +8
# Progress: 3939/4902 | accepted={0: 0, 1: 772, 2: 1043, 3: 2124} | Time elapsed=48.88 mins | Score 1 +26
# Progress: 3954/4902 | accepted={0: 0, 1: 772, 2: 1058, 3: 2124} | Time elapsed=49.05 mins | Score 2 +15
# Progress: 3965/4902 | accepted={0: 0, 1: 772, 2: 1058, 3: 2135} | Time elapsed=49.29 mins | Score 3 +11
# Progress: 3980/4902 | accepted={0: 0, 1: 772, 2: 1058, 3: 2150} | Time elapsed=49.44 mins | Score 3 +15
# Progress: 4010/4902 | accepted={0: 0, 1: 772, 2: 1088, 3: 2150} | Time elapsed=49.62 mins | Score 2 +30
# Progress: 4035/4902 | accepted={0: 0, 1: 797, 2: 1088, 3: 2150} | Time elapsed=49.78 mins | Score 1 +25
# Progress: 4042/4902 | accepted={0: 0, 1: 797, 2: 1088, 3: 2157} | Time elapsed=49.98 mins | Score 3 +7
# Progress: 4052/4902 | accepted={0: 0, 1: 797, 2: 1088, 3: 2167} | Time elapsed=50.25 mins | Score 3 +10
# Progress: 4075/4902 | accepted={0: 0, 1: 797, 2: 1111, 3: 2167} | Time elapsed=50.41 mins | Score 2 +23
# Progress: 4087/4902 | accepted={0: 0, 1: 797, 2: 1111, 3: 2179} | Time elapsed=50.62 mins | Score 3 +12
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The dark-colored material will absorb the sun's rays faster, causing the dog house to heat up more quickly compared to a lighter color.",
# "The white color will not have a significant effect on the dog house, as it does not absorb much heat, allowi
# Progress: 4113/4902 | accepted={0: 0, 1: 823, 2: 1111, 3: 2179} | Time elapsed=50.95 mins | Score 1 +26
# Progress: 4123/4902 | accepted={0: 0, 1: 823, 2: 1111, 3: 2189} | Time elapsed=51.16 mins | Score 3 +10
# Progress: 4131/4902 | accepted={0: 0, 1: 823, 2: 1111, 3: 2197} | Time elapsed=51.27 mins | Score 3 +8
# Progress: 4155/4902 | accepted={0: 0, 1: 823, 2: 1135, 3: 2197} | Time elapsed=51.48 mins | Score 2 +24
# Progress: 4168/4902 | accepted={0: 0, 1: 823, 2: 1135, 3: 2210} | Time elapsed=51.64 mins | Score 3 +13
# Progress: 4195/4902 | accepted={0: 0, 1: 850, 2: 1135, 3: 2210} | Time elapsed=51.84 mins | Score 1 +27
# Progress: 4213/4902 | accepted={0: 0, 1: 850, 2: 1135, 3: 2228} | Time elapsed=52.05 mins | Score 3 +18
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The passage begins by highlighting the harmful effects of space junk, then delves into the problem of collisions between dead satellites. It acknowledges that some may not see space trash as a major issue, but argues that it is a significant probl
# Progress: 4234/4902 | accepted={0: 0, 1: 850, 2: 1156, 3: 2228} | Time elapsed=52.46 mins | Score 2 +21
# Progress: 4255/4902 | accepted={0: 0, 1: 871, 2: 1156, 3: 2228} | Time elapsed=52.62 mins | Score 1 +21
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "Examining the results from the polymer lab, it is evident that plastic type B stretched the furthest compared to the other materials. To improve the experiment, the students could have provided specific instructions on the amount of weight to be a
# Progress: 4267/4902 | accepted={0: 0, 1: 871, 2: 1156, 3: 2240} | Time elapsed=53.08 mins | Score 3 +12
# Progress: 4294/4902 | accepted={0: 0, 1: 871, 2: 1183, 3: 2240} | Time elapsed=53.34 mins | Score 2 +27
# Progress: 4301/4902 | accepted={0: 0, 1: 871, 2: 1183, 3: 2247} | Time elapsed=53.50 mins | Score 3 +7
# Progress: 4329/4902 | accepted={0: 0, 1: 899, 2: 1183, 3: 2247} | Time elapsed=53.64 mins | Score 1 +28
# Progress: 4342/4902 | accepted={0: 0, 1: 899, 2: 1183, 3: 2260} | Time elapsed=53.79 mins | Score 3 +13
# Progress: 4354/4902 | accepted={0: 0, 1: 899, 2: 1183, 3: 2272} | Time elapsed=53.94 mins | Score 3 +12
# Progress: 4372/4902 | accepted={0: 0, 1: 899, 2: 1201, 3: 2272} | Time elapsed=54.09 mins | Score 2 +18
# Progress: 4388/4902 | accepted={0: 0, 1: 899, 2: 1201, 3: 2288} | Time elapsed=54.27 mins | Score 3 +16
# Progress: 4409/4902 | accepted={0: 0, 1: 920, 2: 1201, 3: 2288} | Time elapsed=54.41 mins | Score 1 +21
# Progress: 4436/4902 | accepted={0: 0, 1: 920, 2: 1228, 3: 2288} | Time elapsed=54.56 mins | Score 2 +27
# Progress: 4462/4902 | accepted={0: 26, 1: 920, 2: 1228, 3: 2288} | Time elapsed=54.70 mins | Score 0 +26
# Progress: 4471/4902 | accepted={0: 26, 1: 920, 2: 1228, 3: 2297} | Time elapsed=54.78 mins | Score 3 +9
# Progress: 4498/4902 | accepted={0: 26, 1: 947, 2: 1228, 3: 2297} | Time elapsed=54.93 mins | Score 1 +27
# Progress: 4512/4902 | accepted={0: 26, 1: 947, 2: 1228, 3: 2311} | Time elapsed=55.13 mins | Score 3 +14
# Progress: 4538/4902 | accepted={0: 26, 1: 947, 2: 1254, 3: 2311} | Time elapsed=55.38 mins | Score 2 +26
# Progress: 4550/4902 | accepted={0: 26, 1: 947, 2: 1254, 3: 2323} | Time elapsed=55.54 mins | Score 3 +12
# Progress: 4571/4902 | accepted={0: 47, 1: 947, 2: 1254, 3: 2323} | Time elapsed=55.66 mins | Score 0 +21
# Progress: 4600/4902 | accepted={0: 47, 1: 976, 2: 1254, 3: 2323} | Time elapsed=55.83 mins | Score 1 +29
# Progress: 4616/4902 | accepted={0: 47, 1: 976, 2: 1254, 3: 2339} | Time elapsed=56.07 mins | Score 3 +16
# Progress: 4642/4902 | accepted={0: 47, 1: 976, 2: 1280, 3: 2339} | Time elapsed=56.28 mins | Score 2 +26
# Progress: 4664/4902 | accepted={0: 69, 1: 976, 2: 1280, 3: 2339} | Time elapsed=56.45 mins | Score 0 +22
# Progress: 4678/4902 | accepted={0: 69, 1: 976, 2: 1280, 3: 2353} | Time elapsed=56.61 mins | Score 3 +14
# Progress: 4707/4902 | accepted={0: 69, 1: 1005, 2: 1280, 3: 2353} | Time elapsed=56.81 mins | Score 1 +29
# Progress: 4722/4902 | accepted={0: 69, 1: 1005, 2: 1280, 3: 2368} | Time elapsed=57.03 mins | Score 3 +15
# Progress: 4743/4902 | accepted={0: 90, 1: 1005, 2: 1280, 3: 2368} | Time elapsed=57.17 mins | Score 0 +21
# Progress: 4767/4902 | accepted={0: 90, 1: 1005, 2: 1304, 3: 2368} | Time elapsed=57.38 mins | Score 2 +24
# Progress: 4776/4902 | accepted={0: 90, 1: 1005, 2: 1304, 3: 2377} | Time elapsed=57.52 mins | Score 3 +9
# Progress: 4797/4902 | accepted={0: 111, 1: 1005, 2: 1304, 3: 2377} | Time elapsed=57.65 mins | Score 0 +21
# Progress: 4804/4902 | accepted={0: 111, 1: 1005, 2: 1304, 3: 2384} | Time elapsed=57.82 mins | Score 3 +7
# Progress: 4831/4902 | accepted={0: 111, 1: 1032, 2: 1304, 3: 2384} | Time elapsed=57.96 mins | Score 1 +27
# Progress: 4858/4902 | accepted={0: 111, 1: 1032, 2: 1331, 3: 2384} | Time elapsed=58.13 mins | Score 2 +27
# Progress: 4867/4902 | accepted={0: 111, 1: 1032, 2: 1331, 3: 2393} | Time elapsed=58.26 mins | Score 3 +9
# Progress: 4879/4902 | accepted={0: 111, 1: 1032, 2: 1331, 3: 2405} | Time elapsed=58.38 mins | Score 3 +12
# Progress: 4879/4902 | accepted={0: 111, 1: 1032, 2: 1331, 3: 2405} | Time elapsed=58.51 mins | Score 0 +0
# Progress: 4892/4902 | accepted={0: 124, 1: 1032, 2: 1331, 3: 2405} | Time elapsed=58.67 mins | Score 0 +13
# Progress: 4898/4902 | accepted={0: 124, 1: 1032, 2: 1331, 3: 2411} | Time elapsed=58.88 mins | Score 3 +6
# Progress: 4901/4902 | accepted={0: 124, 1: 1035, 2: 1331, 3: 2411} | Time elapsed=58.96 mins | Score 1 +3
# Bad JSON from Claude. Retrying. (streak: 1 )
# [
# "The student could specify the amount of weight used in the experiment. They could also increase the weight for the second trial. Additionally, they should perform the trial at least 3 times to improve the validity of the results. The student shoul
# Progress: 4902/4902 | accepted={0: 124, 1: 1035, 2: 1332, 3: 2411} | Time elapsed=59.43 mins | Score 2 +1
# Generation done. New rows created: 4902

# %%
file_new = pd.DataFrame(new_rows)

combined = pd.concat([file, file_new], ignore_index=True)

combined["EssayText"] = combined["EssayText"].map(clean_rows)
combined["type"] = combined["type"].fillna("").astype(str).str.strip().str.lower()

orig = combined[combined["type"] != "paraphrased"].copy()
para = combined[combined["type"] == "paraphrased"].copy()

# Remove paraphrase–paraphrase duplicates within the same score (normalized) TEMPORARILY
para["_norm"] = para["EssayText"].map(clean_rows)
para = para.drop_duplicates(subset=["Score2", "_norm"], keep="first").copy()
para = para.drop(columns=["_norm"])

# Remove paraphrases that replicate an original within the same score (normalized) TEMPORARILY
orig["_norm"] = orig["EssayText"].map(clean_rows)
orig_keys = set(zip(orig["Score2"], orig["_norm"]))

para["_norm"] = para["EssayText"].map(clean_rows)
para = para[~para.apply(lambda r: (r["Score2"], r["_norm"]) in orig_keys, axis=1)].copy()

para = para.drop(columns=["_norm"])
orig = orig.drop(columns=["_norm"])

final_22000 = pd.concat([orig, para], ignore_index=True)

print("Original rows: ", len(orig))
print("Total rows in dataset after augmenting to 22000: ", len(final_22000))
print(final_22000["Score2"].value_counts().sort_index())

# Final check to see if there's no paraphrased dupes (TEMPORARY norm column)
paraRows = final_22000[final_22000["type"] == "paraphrased"].copy()
paraRows["_norm"] = paraRows["EssayText"].map(clean_rows)
dupe_para = paraRows.duplicated(subset=["Score2", "_norm"], keep=False).sum()
print("Paraphrased duplicate rows involved:", dupe_para)

# Paraphrased duplicate rows per score (TEMPORARY norm column)
dupes_per_score = (
    paraRows.duplicated(subset=["Score2", "_norm"], keep=False)
           .groupby(paraRows["Score2"])
           .sum()
)

print("Paraphrased duplicate rows per score:")
print(dupes_per_score)

# Total number of extra duplicate paraphrase copies (TEMPORARY norm column)
dupes = paraRows.duplicated(subset=["Score2", "_norm"]).sum()

counts = final_22000["Score2"].value_counts().sort_index()

print("Dupes per score (paraphrased only):", dupes)
print("Counts:", counts.to_dict(), "Total:", len(final_22000))

# Clean up temp column in paraRows (final_22000 never had it)
paraRows = paraRows.drop(columns=["_norm"])
# Out:
# Original rows:  13765
# Total rows in dataset after augmenting to 22000:  22127
# Score2
# 0    5548
# 1    5553
# 2    5526
# 3    5500
# Name: count, dtype: int64
# Paraphrased duplicate rows involved: 0
# Paraphrased duplicate rows per score:
# Score2
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64
# Dupes per score (paraphrased only): 0
# Counts: {0: 5548, 1: 5553, 2: 5526, 3: 5500} Total: 22127

# %%
save = "/content/drive/MyDrive/Data Augmentation/Claude/claude_22000"
outfile = f"{save}/complete_augment_22000.csv"

#keep ONLY these columns (this removes EssayText_norm if it exists)
final_22000 = final_22000[["EssayText", "Score2", "type"]].copy()

final_22000.to_csv(outfile, index=False)
print("Saved:", outfile)
# Out:
# Saved: /content/drive/MyDrive/Data Augmentation/Claude/claude_22000/complete_augment_22000.csv

# %%
#      !!!!!!!!!!!!    NO NEED TO HAVE THIS  !!!!!!!!!!
#The augmented dataset can be a bit more than 22000 as long as there is not a big gap between the scores

target = 5500

# originals stay EXACTLY as they are
original = final_22000[final_22000["type"] != "paraphrased"].copy()

# paraphrases only (order preserved)
paraphrased = final_22000[final_22000["type"] == "paraphrased"].copy()

# trim paraphrases per score WITHOUT reordering
kept_paras = []

for s in [0,1,2,3]:
    orig_count = (original["Score2"] == s).sum()
    para_needed = target - orig_count

    if para_needed < 0:
        raise ValueError(f"Score {s} has more than {target} originals")

    para_s = paraphrased[paraphrased["Score2"] == s]

    # keep ONLY what is needed, in original order
    kept_paras.append(para_s.iloc[:para_needed])

# concatenate paraphrases (still in original appearance order)
paraphrased_trimmed = pd.concat(kept_paras)

# FINAL ORDER: originals first, paraphrases after
final_exact_22000 = pd.concat(
    [original, paraphrased_trimmed],
    ignore_index=True
)

print("Final counts:")
print(final_exact_22000["Score2"].value_counts().sort_index())
print("Total rows:", len(final_exact_22000))
# Out:
# Final counts:
# Score2
# 0    5500
# 1    5500
# 2    5500
# 3    5500
# Name: count, dtype: int64
# Total rows: 22000

# %%
savepath = "/content/drive/MyDrive/Data Augmentation/Claude/claude_22000"
outpath = f"{savepath}/final_exact_22000.csv"

# keep ONLY these columns (this removes EssayText_norm if it exists)
final_exact_22000 = final_exact_22000[["EssayText", "Score2", "type"]].copy()

final_exact_22000.to_csv(outpath, index=False)
print("Saved:", outpath)
print("Rows:", len(final_exact_22000))
print(final_exact_22000["Score2"].value_counts().sort_index())
# Out:
# Saved: /content/drive/MyDrive/Data Augmentation/Claude/claude_22000/final_exact_22000.csv
# Rows: 22000
# Score2
# 0    5500
# 1    5500
# 2    5500
# 3    5500
# Name: count, dtype: int64

# %%
file = pd.read_csv("/content/drive/MyDrive/Data Augmentation/Claude/claude_22000/final_claude_22000.csv")
fd_3 = file[file["Score2"].isin([0])]

s = 2
fd = file[file["Score2"] == s].copy()

dupes = fd.duplicated(subset=["EssayText"], keep=False).sum()
print(f"Exact duplicates for score {s}: {dupes}")
# Out:
# Exact duplicates for score 2: 52

# %%
file = pd.read_csv("/content/drive/MyDrive/Data Augmentation/Claude/claude_22000/augment_22000_(HASDUPES).csv")
print("Saved: ", len(file))
print(file["Score2"].value_counts().sort_index())
# Out:
# Saved:  22000
# Score2
# 0    5500
# 1    5500
# 2    5500
# 3    5500
# Name: count, dtype: int64
